# %% [markdown]
# ###### import modules

# %%
import os,sys,folium
src = r'../../../src'
sys.path.append(os.path.abspath(src))
import twtnamelist,twtmapfolium

# %% [markdown]
# ###### initialize namelist object

# %%
fname_namelist = '../namelist.yaml'
namelist = twtnamelist.Namelist(filename=fname_namelist)

# %% [markdown]
# ###### make twi map and show

# %%
map = twtmapfolium.twtfoliummap(namelist=namelist)
map.add_nonperennial_strm_classification(namelist=namelist)
map.add_perennial_strm_classification(namelist=namelist)
folium.LayerControl().add_to(map)
display(map)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: ERROR _add_nhd could not find u:\NonPerennialStreamPOC\examples\buckhorn\input\051002010506\nhd_hr.gpkg
# C:\Users\GEVENSON\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3554: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
